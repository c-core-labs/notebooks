# %% [markdown]
# # Find Sentinel 1 acquisitions that overlap with STK intervals
#
# For convenience, the badge below launches this notebook on Google [Colab](https://colab.research.google.com/).
#
# <a target="_blank" href="https://colab.research.google.com/github/c-core-labs/notebooks/blob/master/notebooks/sentinel-1-acquisitions.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# ## Install dependencies

# %%
import sys
# !{sys.executable} -m pip install pandas python-dateutil sentinelsat
# Out:
# Requirement already satisfied: pandas in /home/jhetzel/.cache/pypoetry/virtualenvs/notebooks-jou60wtj-py3.10/lib/python3.10/site-packages (1.5.1)
# Requirement already satisfied: python-dateutil in /home/jhetzel/.cache/pypoetry/virtualenvs/notebooks-jou60wtj-py3.10/lib/python3.10/site-packages (2.8.2)
# Requirement already satisfied: sentinelsat in /home/jhetzel/.cache/pypoetry/virtualenvs/notebooks-jou60wtj-py3.10/lib/python3.10/site-packages (1.1.1)
# Requirement already satisfied: pytz>=2020.1 in /home/jhetzel/.cache/pypoetry/virtualenvs/notebooks-jou60wtj-py3.10/lib/python3.10/site-packages (from pandas) (2022.6)
# Requirement already satisfied: numpy>=1.21.0 in /home/jhetzel/.cache/pypoetry/virtualenvs/notebooks-jou60wtj-py3.10/lib/python3.10/site-packages (from pandas) (1.23.4)
# Requirement already satisfied: six>=1.5 in /home/jhetzel/.cache/pypoetry/virtualenvs/notebooks-jou60wtj-py3.10/lib/python3.10/site-packages (from python-dateutil) (1.16.0)
# Requirement already satisfied: tqdm>=4.58 in /home/jhetzel/.cache/pypoetry/virtualenvs/notebooks-jou60wtj-py3.10/lib/python3.10/site-packages (from sentinelsat) (4.64.1)
# Requirement already satisfied: geomet in /home/jhetzel/.cache/pypoetry/virtualenvs/notebooks-jou60wtj-py3.10/lib/python3.10/site-packages (from sentinelsat) (1.0.0)
# Requirement already satisfied: geojson>=2 in /home/jhetzel/.cache/pypoetry/virtualenvs/notebooks-jou60wtj-py3.10/lib/python3.10/site-packages (from sentinelsat) (2.5.0)
# Requirement already satisfied: html2text in /home/jhetzel/.cache/pypoetry/virtualenvs/notebooks-jou60wtj-py3.10/lib/python3.10/site-packages (from sentinelsat) (2020.1.16)
# Requirement already satisfied: click>=7.1 in /home/jhetzel/.cache/pypoetry/virtualenvs/notebooks-jou60wtj-py3.10/lib/python3.10/site-packages (from sentinelsat) (8.1.3)
# Requirement already satisfied: requests in /home/jhetzel/.cache/pypoetry/virtualenvs/notebooks-jou60wtj-py3.10/lib/python3.10/site-packages (from sentinelsat) (2.28.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/jhetzel/.cache/pypoetry/virtualenvs/notebooks-jou60wtj-py3.10/lib/python3.10/site-packages (from requests->sentinelsat) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jhetzel/.cache/pypoetry/virtualenvs/notebooks-jou60wtj-py3.10/lib/python3.10/site-packages (from requests->sentinelsat) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/jhetzel/.cache/pypoetry/virtualenvs/notebooks-jou60wtj-py3.10/lib/python3.10/site-packages (from requests->sentinelsat) (1.26.12)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/jhetzel/.cache/pypoetry/virtualenvs/notebooks-jou60wtj-py3.10/lib/python3.10/site-packages (from requests->sentinelsat) (2.1.1)
#
# [notice] A new release of pip available: 22.3.1 -> 23.0
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ## Import dependencies

# %%
from typing import Dict
import datetime
import pandas as pd
from dateutil.parser import parse
from sentinelsat import SentinelAPI, geojson_to_wkt

# %% [markdown]
# ## SCIHUB credentials

# %%
scihub_username = ""
scihub_password = ""

# %% [markdown]
# ## Path to STK output

# %%
path = "sentinel-1-acquisitions.txt"

# %% [markdown]
# ## Convenience functions to extract start and stop datetimes and data types

# %%
def get_start(line: str):
    line_stripped = line.strip()
    start = parse("-".join(line_stripped.split()[1:5]))
    
    return start


def get_end(line: str):
    line_stripped = line.strip()
    start = parse("-".join(line_stripped.split()[5:9]))
    
    return start


def items_to_row(items):
    """Given a list or Sentinel 1 items, summarize which data types are available."""
    row = {
        "raw": False, 
        "grd": False,  
        "slc": False,  
        "ocn": False, 
        "raw_duration": None, 
        "grd_duration": None,
        "slc_duration": None,
        "ocn_duration": None,
        "raw_id": None,
        "grd_id": None,
        "slc_id": None,
        "ocn_id": None,
    }
    for item in items:
        data_type = item["producttype"].lower()
        duration = item["endposition"] - item["beginposition"]
        duration = duration.seconds
        id = item["identifier"]

        row[data_type] = True
        row[f"{data_type}_duration"] = duration
        row[f"{data_type}_id"] = id
        
        
    return row

# %% [markdown]
# ## Search for Sentinel 1 acquisitions, filtering by millisecond precision
# The default search API appears to miss acquisitions if datetime interval is less than a minute.
# This function buffers the datetime interval for the search API, and performs a final precise datetime filter in memory.

# %%
def search(
    datetime_start: datetime.datetime,
    datetime_end: datetime.datetime,
    platformname: str = "Sentinel-1",
    timedelta: int = 1,
    verbose: bool = False,
) -> Dict:
    """
    Search Sentinel Hub
    """
    api = SentinelAPI(scihub_username, scihub_password)

    datetime_start_buffered = datetime_start - datetime.timedelta(minutes=timedelta)
    datetime_end_buffered = datetime_end + datetime.timedelta(minutes=timedelta)
    
    if verbose:
        print("Precise datetime range", datetime_start, datetime_end)
        print("Buffered datetime range",datetime_start_buffered, datetime_end_buffered)
    
    results = api.query(
        date=(datetime_start_buffered, datetime_end_buffered),
        platformname=platformname
    )

    items = [item[1] for item in list(results.items()) if item[1]["beginposition"] <= datetime_start and item[1]["endposition"] >= datetime_start]
    row = items_to_row(items)
    
    if len(items):

# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18  S1A_EW_RAW__0SDV_20220601T143724_20220601T1438...
# 19                                               None
# 20  S1A_IW_RAW__0SDV_20220630T164218_20220630T1642...
# 21                                               None
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                               None
# 26  S1A_IW_RAW__0SDV_20221110T172139_20221110T1722...
# 27  S1A_IW_RAW__0SDV_20221117T111503_20221117T1115...
# 28                                               None
# 29                                               None
# 30  S1A_IW_RAW__0SDV_20221126T054248_20221126T0543...
# 31                                               None
# 32  S1A_IW_RAW__0SDV_20230108T182257_20230108T1823...
# 33                                               None
# 34                                               None
# 35                                               None
# 36                                               None
# 37                                               None
# 38                                               None
# 39                                               None
#
#                                                grd_id  \
# 0   S1A_IW_GRDH_1SDV_20220207T055356_20220207T0554...
# 1                                                None
# 2                                                None
# 3                                                None
# 4   S1A_IW_GRDH_1SDV_20220305T060040_20220305T0601...
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9   S1A_IW_GRDH_1SDV_20220409T130803_20220409T1308...
# 10                                               None
# 11                                               None
# 12                                               None
# 13  S1A_IW_GRDH_1SDV_20220502T225721_20220502T2257...
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18  S1A_EW_GRDM_1SDV_20220601T143728_20220601T1438...
# 19                                               None
# 20  S1A_IW_GRDH_1SDV_20220630T164156_20220630T1642...
# 21                                               None
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                               None
# 26  S1A_IW_GRDH_1SDV_20221110T172143_20221110T1722...
# 27  S1A_IW_GRDH_1SDV_20221117T111502_20221117T1115...
# 28                                               None
# 29                                               None
# 30  S1A_IW_GRDH_1SDV_20221126T054251_20221126T0543...
# 31                                               None
# 32  S1A_IW_GRDH_1SDV_20230108T182326_20230108T1823...
# 33                                               None
# 34                                               None
# 35                                               None
# 36                                               None
# 37                                               None
# 38                                               None
# 39                                               None
#
#                                                slc_id  \
# 0   S1A_IW_SLC__1SDV_20220207T055356_20220207T0554...
# 1                                                None
# 2                                                None
# 3                                                None
# 4   S1A_IW_SLC__1SDV_20220305T060039_20220305T0601...
# 5                                                None
# 6                                                None
# 7   S1A_WV_SLC__1SSV_20220313T162301_20220313T1631...
# 8                                                None
# 9   S1A_IW_SLC__1SDV_20220409T130737_20220409T1308...
# 10                                               None
# 11                                               None
# 12                                               None
# 13  S1A_IW_SLC__1SDV_20220502T225720_20220502T2257...
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18                                               None
# 19                                               None
# 20  S1A_IW_SLC__1SDV_20220630T164155_20220630T1642...
# 21                                               None
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                               None
# 26  S1A_IW_SLC__1SDV_20221110T172142_20221110T1722...
# 27  S1A_IW_SLC__1SDV_20221117T111502_20221117T1115...
# 28                                               None
# 29                                               None
# 30  S1A_IW_SLC__1SDV_20221126T054250_20221126T0543...
# 31                                               None
# 32  S1A_IW_SLC__1SDV_20230108T182325_20230108T1823...
# 33                                               None
# 34                                               None
# 35                                               None
# 36                                               None
# 37                                               None
# 38                                               None
# 39  S1A_WV_SLC__1SSV_20230201T184357_20230201T1900...
#
#                                                ocn_id
# 0   S1A_IW_OCN__2SDV_20220207T055356_20220207T0554...
# 1                                                None
# 2                                                None
# 3                                                None
# 4                                                None
# 5                                                None
# 6                                                None
# 7   S1A_WV_OCN__2SSV_20220313T162301_20220313T1631...
# 8                                                None
# 9                                                None
# 10                                               None
# 11                                               None
# 12                                               None
# 13  S1A_IW_OCN__2SDV_20220502T225721_20220502T2257...
# 14                                               None
# 15                                               None
# 16                                               None
# 17                                               None
# 18  S1A_EW_OCN__2SDV_20220601T143728_20220601T1438...
# 19                                               None
# 20                                               None
# 21                                               None
# 22                                               None
# 23                                               None
# 24                                               None
# 25                                               None
# 26  S1A_IW_OCN__2SDV_20221110T172143_20221110T1722...
# 27  S1A_IW_OCN__2SDV_20221117T111502_20221117T1115...
# 28                                               None
# 29                                               None
# 30                                               None
# 31                                               None
# 32  S1A_IW_OCN__2SDV_20230108T182326_20230108T1823...
# 33                                               None
# 34                                               None
# 35                                               None
# 36                                               None
# 37                                               None
# 38                                               None
# 39  S1A_WV_OCN__2SSV_20230201T184357_20230201T1900...

# %% [markdown]
# ## Save acquisition results to csv file

# %%
start_date = acquisitions.iloc[0].start.isoformat()
csv_filename = f"{start_date}.csv"
acquisitions.to_csv(csv_filename)
print(f"CSV file saved to {csv_filename}")
# Out:
# CSV file saved to 2022-02-07T05:54:08.340000.csv
